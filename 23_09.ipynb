# %%
l1, l2 = [1,2,3,4], ["a", "b", "c", "d"]
# Ciclo in parallelo su più liste
for v1, v2 in zip(l1, l2):
    print(v1, v2)
# Out:
# 1 a
# 2 b
# 3 c
# 4 d

# %%
import random

# %%
lettere = "abcdefghijklmnopqrstuvwxyz"
# random.choices(lettere, k = 10)
"".join(random.choices(lettere, k = 5))
# Out:
# 'measx'

# %%
d = { i:"".join(random.choices(lettere, k = 5)) for i in range (150000)}
print(d)
for i in d:
    if d[i] == "nigga" or d[i] == "negro" or d[i] == "viale":
        print(f"\n\n\nSIIIIII {i}")
# Out:
# {0: 'fjozr', 1: 'upand', 2: 'vwaex', 3: 'zcqcz', 4: 'vfyup', 5: 'natan', 6: 'dvtff', 7: 'vxpvu', 8: 'ogqal', 9: 'qalta', 10: 'bywdt', 11: 'vkloj', 12: 'avsqg', 13: 'vgbkz', 14: 'itgtw', 15: 'guaqi', 16: 'kqqki', 17: 'pzugj', 18: 'qjmvq', 19: 'vgsmf', 20: 'qnmdk', 21: 'rwdgr', 22: 'ungfx', 23: 'qgzmq', 24: 'mfckp', 25: 'uogdo', 26: 'gojbe', 27: 'fnsxr', 28: 'enujj', 29: 'vfzvm', 30: 'iazad', 31: 'atmbi', 32: 'wscoq', 33: 'jcnqr', 34: 'zkyrq', 35: 'awdae', 36: 'vcorp', 37: 'zuvnk', 38: 'mhdbx', 39: 'mxdvv', 40: 'qhrnn', 41: 'znsqh', 42: 'dpsba', 43: 'pprjo', 44: 'bhzgw', 45: 'xdmwe', 46: 'egjmk', 47: 'rbxar', 48: 'ekawg', 49: 'ksgin', 50: 'cplnd', 51: 'lqyft', 52: 'mshtl', 53: 'ycozv', 54: 'qwdrr', 55: 'kgokr', 56: 'pchmh', 57: 'ylhad', 58: 'htxke', 59: 'kifsa', 60: 'mqgfi', 61: 'qggop', 62: 'wvwpc', 63: 'yonkd', 64: 'ixeiv', 65: 'reaxw', 66: 'zzrct', 67: 'tpyec', 68: 'ieuhh', 69: 'cpjcq', 70: 'bmicp', 71: 'rgwkn', 72: 'ocmor', 73: 'ylpxj', 74: 'gqsfo', 75: 'mynsx', 76: 'zmved', 77: 'yfthi', 78: 'kxmoh', 79: 'qlwtm', 80: 'fbzoe', 81: 'ujhgv', 82: 'gyobh', 83: 'hulac', 84: 'nqrev', 85: 'egrqs', 86: 'pxuzi', 87: 'igljg', 88: 'rharx', 89: 'sykpz', 90: 'bfipu', 91: 'lymca', 92: 'lpoac', 93: 'nsoul', 94: 'wbkxf', 95: 'wrmxq', 96: 'oravv', 97: 'msghu', 98: 'dpljc', 99: 'rwphe', 100: 'nzrwq', 101: 'qshcd', 102: 'lhbjl', 103: 'rehba', 104: 'tnorw', 105: 'yfrwm', 106: 'qagbc', 107: 'hynci', 108: 'ovgzs', 109: 'tmmza', 110: 'pknxf', 111: 'uwovp', 112: 'rdunw', 113: 'mgobu', 114: 'gxgsz', 115: 'haveg', 116: 'uqhtq', 117: 'xbmfe', 118: 'mwrbt', 119: 'hqkrn', 120: 'patto', 121: 'lvzqx', 122: 'znanr', 123: 'kpfvh', 124: 'krigy', 125: 'ztgrl', 126: 'jswaq', 127: 'wplow', 128: 'xmogg', 129: 'vnufo', 130: 'qpnyq', 131: 'zfexf', 132: 'arsig', 133: 'oiqrf', 134: 'mhrza', 135: 'tekcj', 136: 'redaz', 137: 'pblsx', 138: 'pumes', 139: 'bytjx', 140: 'lqvte', 141: 'fegyq', 142: 'kopdf', 143: 'qkwms', 144: 'kyuzy', 145: 'stxlv', 146: 'cbxvk', 147: 'cprre', 148: 'wdqiv', 149: 'dxdru', 150: 'lneqs', 151: 'nvtfa', 152: 'ujgin', 153: 'kutjx', 154: 'ocxdd', 155: 'sgivz', 156: 'msqfr', 157: 'oncto', 158: 'wahmw', 159: 'csytc', 160: 'wdowm', 161: 'tlmvu', 162: 'qqllr', 163: 'xnuts', 164: 'zunnq', 165: 'kmazr', 166: 'bszvs', 167: 'lksfb', 168: 'srkzp', 169: 'cruyh', 170: 'snfnv', 171: 'rlcwf', 172: 'znfjr', 173: 'czeda', 174: 'kqted', 175: 'wdkce', 176: 'lqtvz', 177: 'elbka', 178: 'nqqof', 179: 'emkkg', 180: 'whpsp', 181: 'yqjoa', 182: 'srhse', 183: 'hpwcl', 184: 'yweqd', 185: 'kszfd', 186: 'nrckp', 187: 'davmh', 188: 'kmihd', 189: 'tcinj', 190: 'ruuts', 191: 'jrctt', 192: 'pjduu', 193: 'tffwc', 194: 'vxttu', 195: 'ingae', 196: 'kdmnv', 197: 'gxliu', 198: 'feugd', 199: 'tsfvg', 200: 'lqgqo', 201: 'faeoq', 202: 'qpjio', 203: 'wugfc', 204: 'djwtj', 205: 'hrglh', 206: 'hyawe', 207: 'nlobi', 208: 'pxtuv', 209: 'wawfy', 210: 'fpmsx', 211: 'rmypk', 212: 'nlbtu', 213: 'tocpi', 214: 'obwhc', 215: 'kotgq', 216: 'bjwvd', 217: 'wloob', 218: 'yddxn', 219: 'jaafm', 220: 'mbchg', 221: 'nxmwq', 222: 'rpebh', 223: 'xkjqj', 224: 'axlav', 225: 'ywufq', 226: 'tcxnq', 227: 'kylue', 228: 'gphpe', 229: 'kjixi', 230: 'cqsod', 231: 'kxbau', 232: 'rytsc', 233: 'laxzd', 234: 'uaonb', 235: 'ofnym', 236: 'sxlfh', 237: 'buoor', 238: 'rhgze', 239: 'mchdt', 240: 'vhdoz', 241: 'hueon', 242: 'ikdvd', 243: 'zxilk', 244: 'imkhl', 245: 'nlkye', 246: 'yzxnt', 247: 'exaoi', 248: 'apuzh', 249: 'vjghg', 250: 'juauq', 251: 'ivszt', 252: 'pnqnc', 253: 'lbqgw', 254: 'mtrrk', 255: 'yzmin', 256: 'ipqvv', 257: 'fyddk', 258: 'czjji', 259: 'qvyuh', 260: 'amckt', 261: 'kndba', 262: 'tpwhl', 263: 'sospj', 264: 'tfgoj', 265: 'eouiw', 266: 'rawgk', 267: 'dvztg', 268: 'hpgyq', 269: 'axlvg', 270: 'wpwcv', 271: 'kyzun', 272: 'lgbvx', 273: 'jhjfs', 274: 'xhtgv', 275: 'czmla', 276: 'vyekm', 277: 'sayew', 278: 'qczua', 279: 'mrhpn', 280: 'vzxlr', 281: 'smvzu', 282: 'stinu', 283: 'gvhoh', 284: 'pfnjf', 285: 'afxzh', 286: 'tjkre', 287: 'vxtzy', 288: 'ekmyy', 289: 'xdfls', 290: 'vgsix', 291: 'fheiu', 292: 'stkqq', 293: 'n ...
#
#
#
# SIIIIII 56457

# %%
def findchar(text, char):
    return char in text

# %%
# Nome funzione          Parametri   Return
findchar        = lambda text, char: char in text

# %%
d_a = {i:findchar(d[i], "a") for i in d}
d_a
# Out:
# {0: True, 1: False, 2: True, 3: True, 4: False}

# %% [markdown]
# # In Python tutto è un oggetto, anche le funzioni

# %%
somma = lambda a, b: a + b
prodotto = lambda a, b: a * b
operazioni = {"+": somma, "*": prodotto}

# %%
operazioni
# Out:
# {'+': <function __main__.<lambda>(a, b)>,
#  '*': <function __main__.<lambda>(a, b)>}

# %%
op = input("Inserisci '+' per la somma, '*' per il prodotto: ")
a = float(input("Inserisci il primo numero: "))
b = float(input("Inserisci il secondo numero: "))

if op in operazioni:
    print(operazioni[op](a, b))
else:
    print("Operazione non valida 67")
# Out:
# Inserisci '+' per la somma, '*' per il prodotto:  *
# Inserisci il primo numero:  1
# Inserisci il secondo numero:  2
# 2.0

# %%
l = list(range(10))
l2 = l[::-1]
print(l2)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]
